# %%
import numpy as np
import pandas as pd
import seaborn as sb
import seaborn as sns
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
Aviation = pd.read_csv('C:\\Users\\calvi\\Desktop\\Banners\\Aviation.csv', encoding = 'ISO-8859-1')
Aviation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84262 entries, 0 to 84261
# Data columns (total 31 columns):
# Event.Id                  84262 non-null object
# Investigation.Type        84257 non-null object
# Accident.Number           84262 non-null object
# Event.Date                84262 non-null object
# Location                  84185 non-null object
# Country                   83755 non-null object
# Latitude                  30163 non-null float64
# Longitude                 30154 non-null float64
# Airport.Code              47723 non-null object
# Airport.Name              50439 non-null object
# Injury.Severity           84262 non-null object
# Aircraft.Damage           81553 non-null object
# Aircraft.Category         27508 non-null object
# Registration.Number       80412 non-null object
# Make                      84192 non-null object
# Model                     84163 non-null object
# Amateur.Built             83653 non-null object
# ...

# %%
Aviation.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20200102X82407           Accident      WPR20CA055  2019-12-31
# 1  20191231X83852           Accident      CEN20FA049  2019-12-31
# 2  20200102X54844           Accident      ANC20CA011  2019-12-31
# 3  20191230X91852           Accident      CEN20CA048  2019-12-30
# 4  20191228X62945                NaN      WPR20CA053  2019-12-28
#
#         Location        Country   Latitude   Longitude Airport.Code  \
# 0        Elk, CA  United States  39.128611 -123.715833          LLR
# 1     OLATHE, KS  United States  38.846111  -94.736111          OJC
# 2  Fairbanks, AK  United States  64.666945 -148.133334          NaN
# 3   GRANBURY, TX  United States  32.365556  -97.645000          NaN
# 4   Missoula, MT  United States        NaN         NaN          MSO
#
#                Airport.Name  ... Purpose.of.Flight Air.Carrier  \
# 0              Little River  ...          Personal         NaN
# ...

# %%
Aviation.describe()
# Out:
#            Latitude     Longitude  Number.of.Engines  Total.Fatal.Injuries  \
# count  30163.000000  30154.000000       79228.000000          57059.000000
# mean      37.544907    -93.508337           1.146930              0.847614
# std       12.370282     39.454412           0.447004              6.292468
# min      -78.016945   -178.676111           0.000000              0.000000
# 25%       33.307778   -114.861042           1.000000              0.000000
# 50%       38.125278    -94.371667           1.000000              0.000000
# 75%       42.524723    -81.650278           1.000000              1.000000
# max       89.218056    179.618611           8.000000            349.000000
#
#        Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured
# count            54384.000000          55592.000000     69673.000000
# mean                 0.331715              0.518708         5.901325
# std                  1.375602              2.771339        29.534302
# ...

# %%
Data1 = Aviation[(Aviation["Investigation.Type"]=="Accident")]

# %%
Data1
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20200102X82407           Accident      WPR20CA055  2019-12-31
# 1      20191231X83852           Accident      CEN20FA049  2019-12-31
# 2      20200102X54844           Accident      ANC20CA011  2019-12-31
# 3      20191230X91852           Accident      CEN20CA048  2019-12-30
# 5      20191228X23853           Accident      CEN20MA044  2019-12-28
# 6      20191225X93635           Accident      ERA20FA056  2019-12-25
# 7      20191230X95852           Accident      CEN20WA045  2019-12-24
# 9      20191223X91929           Accident      WPR20CA056  2019-12-22
# 10     20191221X83621           Accident      CEN20FA038  2019-12-21
# 11     20191223X54203           Accident      CEN20CA039  2019-12-20
# 12     20191219X84114           Accident      CEN20CA037  2019-12-19
# 13     20191218X74518           Accident      WPR20CA048  2019-12-18
# 14     20191224X43854           Accident      CEN20LA043  2019-12-18
# ...

# %%
Data2=pd.DataFrame(Data1[['Broad.Phase.of.Flight','Aircraft.Damage']])
Data2
# Out:
#       Broad.Phase.of.Flight Aircraft.Damage
# 0                   TAKEOFF     Substantial
# 1                   TAKEOFF       Destroyed
# 2                       NaN     Substantial
# 3                       NaN     Substantial
# 5                   TAKEOFF       Destroyed
# 6                  APPROACH     Substantial
# 7                    CRUISE       Destroyed
# 9                       NaN     Substantial
# 10                 APPROACH       Destroyed
# 11                      NaN     Substantial
# 12                      NaN     Substantial
# 13                      NaN     Substantial
# 14                  LANDING     Substantial
# 15                      NaN     Substantial
# 16                      NaN             NaN
# 17                      NaN     Substantial
# 18                      NaN     Substantial
# 19                      NaN     Substantial
# 20                      NaN     Substantial
# 21                   CRUISE     Substantial
# ...

# %%
Data3 = Data2[(Data2["Aircraft.Damage"]=="Minor")]
Data3
# Out:
#       Broad.Phase.of.Flight Aircraft.Damage
# 114                     NaN           Minor
# 120                    TAXI           Minor
# 150             MANEUVERING           Minor
# 317                 LANDING           Minor
# 749                     NaN           Minor
# 783                     NaN           Minor
# 791                 LANDING           Minor
# 1160                 CRUISE           Minor
# 1167                   TAXI           Minor
# 1194                    NaN           Minor
# 1245                   TAXI           Minor
# 1269                LANDING           Minor
# 1297                    NaN           Minor
# 1435                   TAXI           Minor
# 1510            MANEUVERING           Minor
# 1525                    NaN           Minor
# 1568                   TAXI           Minor
# 1642                   TAXI           Minor
# 1646                LANDING           Minor
# 1831               APPROACH           Minor
# ...

# %% [markdown]
# # Phase of flight which resulted in minor damage to plane

# %%
sb.catplot(y = 'Broad.Phase.of.Flight', data = Data3, kind = 'count')

# %%
pd.crosstab(Data3['Broad.Phase.of.Flight'], Data3['Aircraft.Damage']).T
# Out:
# Broad.Phase.of.Flight  APPROACH  CLIMB  CRUISE  DESCENT  GO-AROUND  LANDING  \
# Aircraft.Damage
# Minor                        62     12      55       19          3      108
#
# Broad.Phase.of.Flight  MANEUVERING  OTHER  STANDING  TAKEOFF  TAXI
# Aircraft.Damage
# Minor                           44      7       115       52   169

# %%
Data4 = Data2[(Data2["Aircraft.Damage"]=="Substantial")]
Data4
# Out:
#       Broad.Phase.of.Flight Aircraft.Damage
# 0                   TAKEOFF     Substantial
# 2                       NaN     Substantial
# 3                       NaN     Substantial
# 6                  APPROACH     Substantial
# 9                       NaN     Substantial
# 11                      NaN     Substantial
# 12                      NaN     Substantial
# 13                      NaN     Substantial
# 14                  LANDING     Substantial
# 15                      NaN     Substantial
# 17                      NaN     Substantial
# 18                      NaN     Substantial
# 19                      NaN     Substantial
# 20                      NaN     Substantial
# 21                   CRUISE     Substantial
# 22                 APPROACH     Substantial
# 24                  TAKEOFF     Substantial
# 26                  LANDING     Substantial
# 28                  TAKEOFF     Substantial
# 30                  TAKEOFF     Substantial
# ...

# %% [markdown]
# # Phase of flight which resulted in substantial damage to plane

# %%
sb.catplot(y = 'Broad.Phase.of.Flight', data = Data4, kind = 'count')

# %%
pd.crosstab(Data4['Broad.Phase.of.Flight'], Data4['Aircraft.Damage']).T
# Out:
# Broad.Phase.of.Flight  APPROACH  CLIMB  CRUISE  DESCENT  GO-AROUND  LANDING  \
# Aircraft.Damage
# Substantial                5646   1254    6898     1402       1215    18914
#
# Broad.Phase.of.Flight  MANEUVERING  OTHER  STANDING  TAKEOFF  TAXI  UNKNOWN
# Aircraft.Damage
# Substantial                   6187     87       767    12381  1951      268

# %%
Data5 = Data2[(Data2["Aircraft.Damage"]=="Destroyed")]
Data5
# Out:
#       Broad.Phase.of.Flight Aircraft.Damage
# 1                   TAKEOFF       Destroyed
# 5                   TAKEOFF       Destroyed
# 7                    CRUISE       Destroyed
# 10                 APPROACH       Destroyed
# 23                  TAKEOFF       Destroyed
# 25                      NaN       Destroyed
# 27                   CRUISE       Destroyed
# 38                  TAKEOFF       Destroyed
# 39                      NaN       Destroyed
# 40                      NaN       Destroyed
# 42                      NaN       Destroyed
# 43                   CRUISE       Destroyed
# 45                   CRUISE       Destroyed
# 49                  TAKEOFF       Destroyed
# 51                  TAKEOFF       Destroyed
# 53                  TAKEOFF       Destroyed
# 61                      NaN       Destroyed
# 69                 APPROACH       Destroyed
# 74                   CRUISE       Destroyed
# 91                 APPROACH       Destroyed
# ...

# %% [markdown]
# # Phase of flight which resulted in plane being destroyed

# %%
sb.catplot(y = 'Broad.Phase.of.Flight', data = Data5, kind = 'count')

# %%
pd.crosstab(Data5['Broad.Phase.of.Flight'], Data5['Aircraft.Damage']).T
# Out:
# Broad.Phase.of.Flight  APPROACH  CLIMB  CRUISE  DESCENT  GO-AROUND  LANDING  \
# Aircraft.Damage
# Destroyed                  2104    815    3573      604        448      831
#
# Broad.Phase.of.Flight  MANEUVERING  OTHER  STANDING  TAKEOFF  TAXI  UNKNOWN
# Aircraft.Damage
# Destroyed                     4032     48       106     3242    67      487
